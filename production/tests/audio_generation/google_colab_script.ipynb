# %% [raw]
# # Install required libraries
# ! pip install gTTS pydub
#
# import os
# from gtts import gTTS
# from pydub import AudioSegment
#
# # --- CONFIGURATION ---
# OUTPUT_DIR = "individual_phone_audio"
# os.makedirs(OUTPUT_DIR, exist_ok=True)
# PHONE_SAMPLE_RATE_HZ = 8000  # Required for phone emulation
#
# # --- TEST SCENARIOS HASH (Dictionary) ---
# # Format simplified to: { 'TEST_CASE_ID': [ (Idioma, Región/TLD, Texto), ... ] }
# test_scenarios = {
#     "allergy_ceph": [
#         # Turn 1: Patient (American English)
#         ("en", "us", "I am allergic to penicillin and amoxicillin. Yesterday they gave me an antibiotic, but I don't know if I can take it."),
#         # Turn 2: Nurse (Mexican Spanish)
#         ("es", "com.mx", "¿Cuál es el nombre del antibiótico?"),
#         # Turn 3: Patient (American English)
#         ("en", "us", "It's name is cephalexin, 500 milligrams."),
#     ],
#
#     "fever_flu": [
#         # Turn 1: Patient (Indian English)
#         ("en", "co.in", "I have a fever, body aches, and chills. I took 500 miligrams of acetaminophen four hours ago, but it hasn't gone down."),
#         # Turn 2: Nurse (Spain Spanish)
#         ("es", "es", "Está bien. ¿Has estado cerca de alguien que haya estado enfermo recientemente?"),
#         # Turn 3: Patient (Indian English)
#         ("en", "co.in", "Yes. My son had the flu last week."),
#     ],
#
#     "cardiac_en_to_es": [
#         # Turn 1: Doctor (Spain Spanish - reading technical report)
#         ("es", "es", "El paciente se presenta con insuficiencia cardíaca aguda descompensada, caracterizada por congestión pulmonar, taquiarritmia supraventricular y elevación progresiva de troponina de alta sensibilidad. La ecocardiografía muestra disfunción sistólica del ventrículo izquierdo con reducción fracción de eyección y signos de hipertensión pulmonar. se indica el monitoreo hemodinámico continuo, junto con la titulación de medicamentos optimización de diuréticos y evaluación inmediata para intervención percutánea intervención coronaria."),
#     ],
#
#     "cardiac_es_to_en": [
#         # Turn 1: Doctor (American English - reading technical report)
#         ("en", "us", "The patient presents with acute decompensated heart failure. Severe pulmonary congestion, supraventricular tachyarrhythmia, and edema. Progressive ultrasensitive troponin. The echocardiogram reveals left ventricular systolic dysfunction. Reduced ejection fraction and signs of pulmonary hypertension. Continuous hemodynamic monitoring, inotropic adjustment. Optimization of diuretics and immediate evaluation for percutaneous coronary intervention."),
#     ],
#
#     "shoulder_pain": [
#         # Turn 1: Doctor (Mexican Spanish)
#         ("es", "com.mx", "Hola, ¿cómo puedo ayudarte hoy?"),
#         # Turn 2: Patient (Latino English)
#         ("en", "com", "I have had shoulder pain for a couple of days that won't go away."),
#         # Turn 3: Doctor (Mexican Spanish)
#         ("es", "com.mx", "¿Recuerdas si hiciste un movimiento extraño o te golpeaste el hombro?"),
#         # Turn 4: Patient (Latino English)
#         ("en", "com", "The pain started last Saturday after playing paddle."),
#     ],
#
#     "allergy_noise": [
#         # Turn 1: Patient (Latino English)
#         ("en", "com", "I'm allergic to penicillin and amoxicillin. Yesterday I was given an antibiotic, but I'm not sure if I can take it."),
#         # Turn 2: Nurse (Spain Spanish)
#         ("es", "es", "¿Cuál es el nombre del antibiótico?"),
#         # Turn 3: Patient (Latino English)
#         ("en", "com", "It's called cephalexin, 500 mg."),
#     ],
#
#     "fatigue_exam": [
#         # Turn 1: Doctor (Spain Spanish - detailed consultation)
#         ("es", "es", "Buenas tardes. Antes de empezar, quiero que se tome su tiempo y me explique con sus propias palabras qué le ha estado molestando en estos últimos días. Cuantos más detalles me dé, más fácil será para mí entender su situación y decidir qué pasos debemos seguir."),
#         # Turn 2: Patient (American English)
#         ("en", "us", "Thank you, doctor. For about five days now I've been feeling a tiredness that isn't normal for me. Even when I sleep well, I wake up without energy. I've also had some muscle aches that come and go, especially in my legs and back."),
#         # Turn 3: Doctor (Spain Spanish)
#         ("es", "es", "Gracias por ser tan detallado, eso ayuda mucho. El cansancio y las molestias musculares pueden deberse a muchas causas diferentes: estrés, infecciones, problemas nutricionales o incluso falta de hidratación adecuada. Me gustaría hacerle algunas preguntas más para acotar las posibilidades: ¿ha notado fiebre, cambios en el apetito o un aumento reciente del estrés?"),
#         # Turn 4: Patient (American English)
#         ("en", "us", "I haven't had a fever, that's for sure. My appetite is a little lower, but I think it's because I feel so tired. As for stress, I've had some pressure at work, but nothing out of the ordinary."),
#         # Turn 5: Doctor (Spain Spanish)
#         ("es", "es", "Entiendo. Gracias por aclararlo. Haremos un par de revisiones básicas, pero por ahora siga describiendo cualquier otra cosa que considere relevante, aunque le parezca menor. A veces los pequeños detalles nos orientan en la dirección correcta."),
#     ],
#
#     "headache_appt": [
#         # Turn 1: Doctor (Mexican Spanish)
#         ("es", "com.mx", "Hola, ¿cómo puedo ayudarte hoy?"),
#         # Turn 2: Patient (Indian English)
#         ("en", "co.in", "Hello, I have a really bad headache, I have been taking paracetamol for three days, but it does not go away. Could you give me something stronger?"),
#         # Turn 3: Doctor (Mexican Spanish)
#         ("es", "com.mx", "Lo siento, no creo que pueda mandarte algo mas fuerte sin verte en persona. Pide una cita y vemos lo que podemos hacer."),
#     ],
#
#     "cough_sob": [
#         # Turn 1: Patient (Spain Spanish)
#         ("es", "es", "I have had a cough since last week, and when I go up stairs I notice that I get short of breath."),
#         # Turn 2: Nurse (American English)
#         ("en", "us", "¿Has notado sibilancias o algún cambio de color en la flema?"),
#         # Turn 3: Patient (Spain Spanish)
#         ("es", "es", "Yes, this morning the phlegm was more yellowish"),
#     ],
# }
#
# print("Generando audios individuales para múltiples escenarios de prueba...")
# print("Downsampling todos los archivos a calidad telefónica (8kHz)...")
#
# # --- MAIN GENERATION LOOP ---
# total_files_generated = 0
#
# for test_case_id, guion_separado in test_scenarios.items():
#     print(f"\n--- Processing Scenario: {test_case_id} ---")
#
#     # The enumerate starts the counter (i) at 0, so we use i+1 for file naming.
#     for i, (idioma, region, texto) in enumerate(guion_separado):
#         # 1. Generate the sequential suffix (001, 002, 003, ...)
#         sequence_suffix = f"{(i + 1):03d}"
#
#         # 2. Construct the final output file name
#         # Format: TC_ID_00i_LANG.wav (e.g., TC_101_MED_PALS_001_EN.wav)
#         language_code = idioma.upper()
#         final_filename = f"{test_case_id}_{sequence_suffix}_{language_code}.wav"
#
#         # 3. GENERATE MP3 (gTTS only outputs MP3)
#         tts = gTTS(text=texto, lang=idioma, tld=region)
#         temp_file = "temp_segment.mp3"
#         tts.save(temp_file)
#
#         # 4. LOAD, DOWN-SAMPLE, AND EXPORT TO WAV (pydub)
#         segmento = AudioSegment.from_mp3(temp_file)
#
#         # CRITICAL: Downsample the audio to 8000 Hz for phone emulation
#         segmento_phone_quality = segmento.set_frame_rate(PHONE_SAMPLE_RATE_HZ)
#
#         # Export the individual segment as a WAV file
#         output_path = os.path.join(OUTPUT_DIR, final_filename)
#         segmento_phone_quality.export(output_path, format="wav")
#
#         # Clean up the temporary MP3 file
#         os.remove(temp_file)
#
#         print(f"✅ Generated: {final_filename}")
#         total_files_generated += 1
#
# print(f"\n--- Generation Complete! ---")
# print(f"Total files generated: {total_files_generated}")
# print(f"All 8kHz WAV files are in the folder '{OUTPUT_DIR}', using the format: ID_00i_LANG.wav")
